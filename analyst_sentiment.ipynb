# %% [markdown]
# # Data Source and Description

# %% [markdown]
# The source of data from https://www.kaggle.com/datasets/andrewmvd/cyberbullying-classification
#
# As social media usage becomes increasingly prevalent in every age group, a vast majority of citizens rely on this essential medium for day-to-day communication. Social media’s ubiquity means that cyberbullying can effectively impact anyone at any time or anywhere, and the relative anonymity
# of the internet makes such personal attacks more difficult to stop than traditional bullying.
#
# On April 15th, 2020, UNICEF issued a warning in response to the increased risk of cyberbullying during the COVID-19 pandemic due to widespread school closures, increased screen time, and decreased face-to-face social interaction. The statistics of cyberbullying are outright alarming: 36.5% of middle and high school students have felt cyberbullied and 87% have observed cyberbullying, with effects ranging from decreased academic performance to depression to suicidal thoughts.
#
# In light of all of this, this dataset contains more than 47000 tweets labelled according to the class of cyberbullying:
#
# * Age;
# * Ethnicity;
# * Gender;
# * Religion;
# * Other type of cyberbullying;
# * Not cyberbullying
#
# The data has been balanced in order to contain ~8000 of each class.

# %%
import pandas as pd

df = pd.read_csv("cyberbullying_tweets.csv")
df.head(5)
# Out:
#                                           tweet_text cyberbullying_type
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# # EDA

# %% [markdown]
# Show Dataset Samples

# %%
def sample_data(df):
    # Describe dataset
    print(f"Dataset Describe:")
    display(df.describe())
    
    # Five head dataset
    print(f"Five Head Dataset:")
    display(df.head())

    # Five Random dataset
    print(f"Five Random Dataset:")
    display(df.sample(5))

    # Five Tail dataset
    print(f"Five Tail Dataset:")
    display(df.tail())

sample_data(df)
# Out:
# Dataset Describe:
#                                                tweet_text cyberbullying_type
# count                                               47692              47692
# unique                                              46017                  6
# top     RT @sailorhg: the intro for my hardware hackin...           religion
# freq                                                    2               7998
# Five Head Dataset:
#                                           tweet_text cyberbullying_type
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
# Five Random Dataset:
#                                               tweet_text cyberbullying_type
# ...

# %% [markdown]
# Dataset Information

# %%
def data_info(df):
    # Dataset Information
    print(f"Dataset Information:")
    display(df.info())

    # Dataset Types
    print(f"Dataset Types:")
    display(df.dtypes)

    # Dataset Shape and Size
    shape_size = pd.DataFrame({'shape': [df.shape], 'size': [df.size]})
    print(f"Dataset Shape:")
    display(shape_size)

data_info(df)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47692 entries, 0 to 47691
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_text          47692 non-null  object
#  1   cyberbullying_type  47692 non-null  object
# dtypes: object(2)
# memory usage: 745.3+ KB
# None
# Dataset Types:
# tweet_text            object
# cyberbullying_type    object
# dtype: object
# Dataset Shape:
#         shape   size
# 0  (47692, 2)  95384

# %% [markdown]
# Check Missing Values and Duplicate Values

# %%
def data_check(df):
    # Missing Values
    missing_values = pd.DataFrame(df.isnull().sum(), columns=['Missing Values'])
    print("Missing Values:")
    display(missing_values.rename_axis('Column'))

    # Duplicate Values
    duplicate_values = pd.DataFrame([df.duplicated().sum()],
                                    columns=['Duplicate Values'], index=['Total'])
    print('Duplicate values of dataset:')
    display(duplicate_values.rename_axis('Count'))

    # Tweet Text Duplicate Values
    tweet_duplicate_values = pd.DataFrame([df['tweet_text'].duplicated().sum()],
                                            columns=['Tweet Text Duplicate Values'], index=['Total'])
    print('Tweet Text Duplicate Values:')
    display(tweet_duplicate_values.rename_axis('Count'))
    
data_check(df)
# Out:
# Missing Values:
#                     Missing Values
# Column
# tweet_text                       0
# cyberbullying_type               0
# Duplicate values of dataset:
#        Duplicate Values
# Count
# Total                36
# Tweet Text Duplicate Values:
#        Tweet Text Duplicate Values
# Count
# Total                         1675

# %% [markdown]
# Check Unique Values

# %%
def unique_data(df):
    # Unique Cyberbullying Types
    unique_types = pd.DataFrame(df['cyberbullying_type'].unique(), columns=['Cyberbullying Types'])
    print('Cyberbullying Types:')
    display(unique_types.rename_axis('Count'))

    # Unique Value Count from Cyberbullying Type
    unique_values_cyberbullying_type = pd.DataFrame(df['cyberbullying_type'].value_counts())
    print('Unique value count from cyber bullying type:')
    display(unique_values_cyberbullying_type)
    
    # Unique Value Count
    unique_count = {col: df[col].nunique() for col in df.columns}
    unique_value_count = pd.DataFrame(unique_count, index=['unique value count'])
    print('Unique value counts of dataset:')
    display(unique_value_count)

unique_data(df)
# Out:
# Cyberbullying Types:
#        Cyberbullying Types
# Count
# 0        not_cyberbullying
# 1                   gender
# 2                 religion
# 3      other_cyberbullying
# 4                      age
# 5                ethnicity
# Unique value count from cyber bullying type:
#                      count
# cyberbullying_type
# religion              7998
# age                   7992
# gender                7973
# ethnicity             7961
# not_cyberbullying     7945
# other_cyberbullying   7823
# Unique value counts of dataset:
#                     tweet_text  cyberbullying_type
# unique value count       46017                   6

# %% [markdown]
# Analysis before Preprocessing
# * Barchart
# * Pie Chart
# * Word Cloud

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar Chart
plt.figure(figsize=(9, 5))
sns.countplot(x='cyberbullying_type', data=df, hue='cyberbullying_type', palette='rocket')
plt.title('Cyberbullying Type')
plt.xlabel('Cyberbullying Type')
plt.ylabel('Count')
plt.show()

# %%
# Pie Chart
cyberbullying_type_count = df['cyberbullying_type'].value_counts()
plt.figure(figsize=(7, 7))
plt.pie(cyberbullying_type_count, labels=cyberbullying_type_count.index, autopct='%1.1f%%', startangle=150, colors=['red', 'green', 'blue', 'grey', 'purple', 'orange'])
plt.title('Cyberbullying Type')
plt.axis('equal')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 1.2))
plt.show()

# %%
# Wordcloud
from wordcloud import WordCloud, STOPWORDS

def wordcloud_before(df):
    for cyberbullying_type in df.cyberbullying_type.unique():
        text = " ".join (i for i in df[df['cyberbullying_type'] == cyberbullying_type]['tweet_text'])
        wordcloud = WordCloud(
                width=900,height=600,background_color='black',stopwords=STOPWORDS,
                min_font_size=10, max_font_size=90
            ).generate(text)

        plt.figure(figsize=(12, 10))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis("off")
        plt.title(f"WordCloud for {cyberbullying_type}")
        plt.show()

wordcloud_before(df)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Delete Duplicate Values

# %%
# Drop Duplicate

# Check Before Drop Duplicate
print(f"Before Drop Duplicate: {len(df)}")
# Drop Duplicate
df_drop_duplicate = df.drop_duplicates(subset='tweet_text')
# Check After Drop Duplicate
print(f"After Drop Duplicate: {len(df_drop_duplicate)}")

df_drop_duplicate.sample(10)
# Out:
# Before Drop Duplicate: 47692
# After Drop Duplicate: 46017
#                                               tweet_text   cyberbullying_type
# 1337   A bunch of people poked me about some article ...    not_cyberbullying
# 20866  @IndyVoices I read the entire Quran and many o...             religion
# 25534  @elenfaith2694 WTH! not again! People are just...  other_cyberbullying
# 16845  Arey madharchod, we bhakts are committed to er...             religion
# 27581  @Aiiane @aquarianfool having better support ne...  other_cyberbullying
# 18956  @dankmtl @PeaceNotHate_ Of course Muslims are ...             religion
# 29891                    Jesus how dumb can you get #mkr  other_cyberbullying
# 35363  The nurses are always the girls that bullied p...                  age
# 27416  RT @ChrisWarcraft: Very cool news from @freebs...  other_cyberbullying
# 39993  I never said they represent all black people ?...            ethnicity

# %% [markdown]
# Lower Case

# %%
import re

def lowercase(text):
    text = text.lower()
    return text

# %%
df['tweet_text'] = df['tweet_text'].apply(lowercase)
df.head()
# Out:
#                                           tweet_text cyberbullying_type
# 0  in other words #katandandre, your food was cra...  not_cyberbullying
# 1  why is #aussietv so white? #mkr #theblock #ima...  not_cyberbullying
# 2  @xochitlsuckkks a classy whore? or more red ve...  not_cyberbullying
# 3  @jason_gio meh. :p  thanks for the heads up, b...  not_cyberbullying
# 4  @rudhoeenglish this is an isis account pretend...  not_cyberbullying

# %% [markdown]
# Remove HTML, Hyperlinks, Mentions and Hashtags

# %%
def html_tag_remover(text):
    text = re.sub(r'<.*?>', '', text) # remove HTML tags
    # remove hyperlinks
    text = re.sub(r'(https?:\/\/)?(www\.)?(\w+\.)*\w+\.\w+(\/[a-zA-Z0-9#]+\/?)*', '', text)
    text = re.sub(r'@[\w_]+', '', text) # remove mentions
    text = re.sub(r'#\w+', '', text) # remove hashtags
    
    return text.strip() # remove leading and trailing whitespaces

# %%
df['tweet_text'] = df['tweet_text'].apply(html_tag_remover)
df.head()
# Out:
#                                           tweet_text cyberbullying_type
# 0       in other words , your food was crapilicious!  not_cyberbullying
# 1                                  why is  so white?  not_cyberbullying
# 2       a classy whore? or more red velvet cupcakes?  not_cyberbullying
# 3  meh. :p  thanks for the heads up, but not too ...  not_cyberbullying
# 4  this is an isis account pretending to be a kur...  not_cyberbullying

# %% [markdown]
# Remove Punctuation

# %%
import string
exclude = string.punctuation

def remove_punctuation(text):
    for char in exclude:
        text = text.replace(char, '')
    return text

# %%
df['tweet_text'] = df['tweet_text'].apply(remove_punctuation)
df.head()
# Out:
#                                           tweet_text cyberbullying_type
# 0         in other words  your food was crapilicious  not_cyberbullying
# 1                                   why is  so white  not_cyberbullying
# 2         a classy whore or more red velvet cupcakes  not_cyberbullying
# 3  meh p  thanks for the heads up but not too con...  not_cyberbullying
# 4  this is an isis account pretending to be a kur...  not_cyberbullying

# %% [markdown]
# Tokenization and Lemmatization

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

def tokenize_lemmatize(text):
    doc = nlp(text)
    lemmas = [token.lemma_ for token in doc]

    return ' '.join(lemmas)

df['tweet_text'] = df['tweet_text'].apply(tokenize_lemmatize)

for i, row in df.head(3).iterrows():
    print(f"Tweet {i+1}:")
    print("Original:", row['tweet_text'])
    lemmas = row['tweet_text']
    print("Lemmatized:", lemmas)
    print()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import spacy
#       3 nlp = spacy.load('en_core_web_sm')
#       5 def tokenize_lemmatize(text):
#
# ModuleNotFoundError: No module named 'spacy'

# %% [markdown]
# Stemming

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

def stemming(text):
    stem_text = ' '.join([ps.stem(word) for word in text.split()])
    return stem_text

# %%
df['tweet_text'] = df['tweet_text'].apply(stemming)
df.head()
# Out:
#                                           tweet_text cyberbullying_type
# 0               in other word your food be crapilici  not_cyberbullying
# 1                                    whi be so white  not_cyberbullying
# 2           a classi whore or more red velvet cupcak  not_cyberbullying
# 3  meh p thank for the head up but not too concer...  not_cyberbullying
# 4  thi be an isi account pretend to be a kurdish ...  not_cyberbullying

# %% [markdown]
# Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()

X_bow = cv.fit_transform(df['tweet_text']).toarray()
y = df['cyberbullying_type']
X_bow.shape
# Out:
# (47692, 34485)

# %% [markdown]
# Tf-Idf Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
X_tfidf = tfidf_vectorizer.fit_transform(df['tweet_text']).toarray()
y = df['cyberbullying_type']
X_tfidf.shape
# Out:
# (47692, 34485)

# %% [markdown]
# BoW and Tf-Idf Combined

# %%
import numpy as np

X_combined = np.hstack((X_bow, X_tfidf))
y = df['cyberbullying_type']
X_combined.shape
# Out:
# (47692, 68970)

# %% [markdown]
# Word Embedding

# %%
from gensim.models import Word2Vec

w2v_sentences = [tweet.split() for tweet in df['tweet_text']]

w2v_model = Word2Vec(w2v_sentences, vector_size=100, window=5, min_count=3)

#w2v_model.save('w2vec_model')
#w2v_model = Word2Vec.load('w2vec_model')

print(f"Vocabulary size: {len(w2v_model.wv.vocab)}")
print(f"Vector size: {w2v_model.wv.vector_size}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 from gensim.models import Word2Vec
#       3 w2v_sentences = [tweet.split() for tweet in df['tweet_text']]
#       5 w2v_model = Word2Vec(w2v_sentences, vector_size=100, window=5, min_count=3)
#
# File c:\Users\WAHYU\Documents\VS Code Project\final test nlp\nlpenv\Lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File c:\Users\WAHYU\Documents\VS Code Project\final test nlp\nlpenv\Lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
# ...

# %%
def get_tweet_vector(tweet, w2v_model):
    if not tweet or not isinstance(tweet, str):
        return np.zeros(w2v_model.vector_size)

    words = tweet.split()
    tweet_words = [word for word in words if word in w2v_model.wv.key_to_index]

    if len(tweet_words) == 0:
        return np.zeros(w2v_model.vector_size)

    tweet_vector = np.mean([w2v_model.wv[word] for word in tweet_words], axis=0)
    return tweet_vector / np.linalg.norm(tweet_vector)
